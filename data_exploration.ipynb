# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: C:\Users\HP\.cache\kagglehub\datasets\dylanjcastillo\7k-books-with-metadata\versions\3

# %%
import pandas as pd 
books=pd.read_csv(f"{path}/books.csv")
books
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
books["missing_description"] = np.where(books['description'].isna(),1,0)
books['age_of_book']=2026-books["published_year"]
columns_of_interest=["num_pages","age_of_book","missing_description","average_rating"]
correlation_matrix= books[columns_of_interest].corr(method="spearman")
sns.set_theme(style="white")
plt.figure(figsize=(8,6))
heatmap=sns.heatmap(correlation_matrix, annot=True, fmt=".2f",cmap="coolwarm",cbar_kws={"label":" Spearman Correlation"})
heatmap.set_title("Correlation")
plt.show()

# %%
cleaned_data=books[~books['description'].isna() & ~books['num_pages'].isna() & ~books['average_rating'].isna() & ~books['published_year'].isna()]
cleaned_data['categories'].value_counts().reset_index().sort_values("count",ascending=False)
cleaned_data['words_in_description']= cleaned_data['description'].str.split().str.len()
cleaned_data.loc[cleaned_data["words_in_description"].between(1,4),"description"]
description_threshold=cleaned_data[cleaned_data["words_in_description"]>=25]
description_threshold
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14764\1846561196.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['words_in_description']= cleaned_data['description'].str.split().str.len()
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# 5     9780006280934  0006280935
# ...             ...         ...
# 6802  9788172235222  8172235224
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# ...

# %%
description_threshold["title_and_subtitle"] = np.where(
    description_threshold["subtitle"].isna(),
    description_threshold["title"],
    description_threshold[["title", "subtitle"]].astype(str).fillna("").agg(": ".join, axis=1)
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14764\150615388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   description_threshold["title_and_subtitle"] = np.where(

# %%
description_threshold["tagged_description"]=description_threshold[["isbn13","description"]].astype(str).agg(" ".join,axis=1)
description_threshold.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14764\3159062593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   description_threshold["tagged_description"]=description_threshold[["isbn13","description"]].astype(str).agg(" ".join,axis=1)
#           isbn13      isbn10                title subtitle  \
# 0  9780002005883  0002005883               Gilead      NaN
# 1  9780002261982  0002261987         Spider's Web  A Novel
# 3  9780006178736  0006178731       Rage of angels      NaN
# 4  9780006280897  0006280897       The Four Loves      NaN
# 5  9780006280934  0006280935  The Problem of Pain      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# ...

# %%
(
    description_threshold
    .drop(["subtitle", "missing_description", "age_of_book", "words_in_description"], axis=1)
    .to_csv("books_cleaned.csv", index=False)
)
